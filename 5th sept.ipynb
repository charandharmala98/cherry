# %% [markdown]
# ### MARKDOWN INTRODUCTION

# %% [markdown]
# # HI
# ## HI
# ### HI
# #### HI
# ##### HI
# ###### HI

# %% [markdown]
# **bold**

# %% [markdown]
# * HAI *

# %% [markdown]
# <strike> striking text </strike>

# %% [markdown]
# * HAI *<br/>
# <strike> hello </strike> <br/>
# `highlighting text`

# %% [markdown]
#  <img src="https://static.makeuseof.com/wp-content/uploads/2018/02/control-arduino-python-670x335.jpg">

# %% [markdown]
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <iframe width="853" height="480" src="https://www.youtube.com/embed/_uQrJ0TkZlc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # PYHTON PROGRAMMING INTRODUCTION

# %% [markdown]
# %%HTML <iframe width="853" height="480" src="https://www.youtube.com/embed/_uQrJ0TkZlc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * python
# * html
# * r programming
# * scripting language
#   -html
#   -xml

# %%
# %%HTML <iframe width="853" height="480" src="https://www.youtube.com/embed/_uQrJ0TkZlc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# UsageError: %%HTML is a cell magic, but the cell body is empty.

# %%
# %%html
# <iframe width="853" height="480" src="https://www.youtube.com/embed/_uQrJ0TkZlc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="853" height="480" src="https://www.youtube.com/embed/_uQrJ0TkZlc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * pyhton
# * ML
# * scripting languages

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %% [markdown]
# # operators

# %% [markdown]
# ### arithmetic operators

# %%
print(98+78)
# Out:
# 176

# %%
print(98-78)
print(98*134)
print(196/24)
# Out:
# 20
# 13132
# 8.166666666666666

# %%
type(1)
# Out:
# int

# %%
type(4)
# Out:
# int

# %%
type(10/3)
# Out:
# float

# %%
10%3
# Out:
# 1

# %%
2**4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %%
pow(99,9)
# Out:
# 913517247483640899

# %% [markdown]
# ### LOGICAL OPERATORS

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True and True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# ### assignment operators

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
a = "hello"

# %%
type(a)
# Out:
# str

# %%
a=b=c=10

# %%
a,b,c
# Out:
# (10, 10, 10)

# %%
int a
# Out:
#   File "<ipython-input-26-0bf1890e5175>", line 1
#     int a
#         ^
# SyntaxError: invalid syntax

# %%
integer a
# Out:
#   File "<ipython-input-27-6fb1f280fa49>", line 1
#     integer a
#             ^
# SyntaxError: invalid syntax

# %%
a=500

# %%
type(a)
# Out:
# int

# %%
a,b,c=1,2,3

# %%
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b=1,2

# %%
a,b=b,a

# %%
print(a,b)
# Out:
# 2 1

# %%
a=1
a
# Out:
# 1

# %%
a = a + 1
a
# Out:
# 2

# %%
a+=1
a
# Out:
# 3

# %%
a += 10
a
# Out:
# 13

# %%
a *+45
a
# Out:
# 13

# %%
a *= 45
a
# Out:
# 585

# %%
a /=3

# %%
a/3
# Out:
# 65.0

# %%
a//5
# Out:
# 39.0

# %% [markdown]
# ### BITWISE OPERATORS

# %%
4 & 7
# Out:
# 4

# %%
4 - 1 0 0
7 - 0 1 1
4 - 1 0 0
# Out:
#   File "<ipython-input-45-59df07596e22>", line 1
#     4 - 1 0 0
#           ^
# SyntaxError: invalid syntax

# %%
7 | 4
# Out:
# 7

# %%
8 << 2
# Out:
# 32

# %%
8 >> 2
# Out:
# 2

# %% [markdown]
# ### Identity operators

# %%
2 == 3
# Out:
# False

# %%
2 is 3
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
2 is not 3
# Out:
# True

# %% [markdown]
# ### Membership operators

# %%
"ap" in "apssdc"
# Out:
# True

# %%
"Ap" in "apssdc"
# Out:
# False

# %%
"a" in "apssdc"
# Out:
# True

# %%
"T"  not in "apssdc"
# Out:
# True
